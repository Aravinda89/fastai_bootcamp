# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravinda89/fastai_bootcamp/blob/main/FKey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastbook kaggle waterfallcharts treeinterpreter dtreeviz
import fastbook
fastbook.setup_book()
import os
from fastbook import *
from IPython.display import Image, display_svg, SVG

from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# !pip install kaggle
# Out:
#      |████████████████████████████████| 727kB 6.7MB/s
#      |████████████████████████████████| 61kB 8.7MB/s
#      |████████████████████████████████| 1.2MB 13.1MB/s
#      |████████████████████████████████| 51kB 9.6MB/s
#      |████████████████████████████████| 194kB 35.8MB/s
#      |████████████████████████████████| 61kB 11.1MB/s
#      |████████████████████████████████| 61kB 10.6MB/s
# ...

# %%
import pandas as pd

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/DataSets/f_keypoints/"
# %cd /content/gdrive/MyDrive/DataSets/f_keypoints/
# Out:
# /content/gdrive/MyDrive/DataSets/f_keypoints

# %% [markdown]
# Download Data

# %%
# !kaggle competitions download -c facial-keypoints-detection

# %%
ls
# Out:
# IdLookupTable.csv  SampleSubmission.csv  test.zip      training.zip
# kaggle.json        test.csv              training.csv

# %%
# file_extract('training.zip')
# file_extract('test.zip')

# %% [markdown]
# Load Data

# %%
# df = pd.read_csv('training.csv')
# df

# %%
df = pd.read_csv('training.csv',header='infer')
df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 7044          67.402546          31.842551           29.746749
# 7045          66.134400          38.365501           30.478626
# 7046          66.690732          36.845221           31.666420
# 7047          70.965082          39.853666           30.543285
# 7048          66.938311          43.424510           31.096059
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
df.shape
# Out:
# (7049, 31)

# %%
df.columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y', 'Image'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 31

# %%
df.loc[0,'left_eye_center_x']
# Out:
# 66.0335639098

# %%
df.loc[0,'left_eye_center_y']
# Out:
# 39.0022736842

# %%
df.loc[0,'Image']
# Out:
# '238 236 237 238 240 240 239 241 241 243 240 239 231 212 190 173 148 122 104 92 79 73 74 73 73 74 81 74 60 64 75 86 93 102 100 105 109 114 121 127 132 134 137 137 140 139 138 137 137 140 141 143 144 147 148 149 147 147 148 145 147 144 146 147 147 143 134 130 130 128 116 104 98 90 82 78 85 88 86 80 77 87 108 111 115 128 133 188 242 252 250 248 251 250 250 250 235 238 236 238 238 237 238 242 241 239 237 233 215 195 187 156 119 103 93 78 68 73 75 75 72 75 70 61 66 77 91 96 106 108 113 120 125 131 134 138 135 138 139 145 144 144 142 140 141 141 148 147 150 149 152 151 149 150 147 148 144 148 144 146 146 143 139 128 132 135 128 112 104 97 87 78 79 83 85 83 75 75 89 109 111 117 117 130 194 243 251 249 250 249 250 251 237 236 237 238 237 238 241 238 238 238 241 221 195 187 163 124 106 95 81 68 70 73 73 72 73 69 65 74 82 94 103 110 111 119 127 135 140 139 144 144 145 143 143 143 146 144 144 147 146 148 147 150 146 147 150 150 149 147 147 144 147 144 149 146 144 144 144 140 131 133 133 125 11
# ...

# %%
len(df.loc[6,'Image'])
# Out:
# 32214

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum()
# Out:
# left_eye_center_x              10
# left_eye_center_y              10
# right_eye_center_x             13
# right_eye_center_y             13
# left_eye_inner_corner_x      4778
# left_eye_inner_corner_y      4778
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# left_eyebrow_inner_end_x     4779
# left_eyebrow_inner_end_y     4779
# left_eyebrow_outer_end_x     4824
# left_eyebrow_outer_end_y     4824
# right_eyebrow_inner_end_x    4779
# right_eyebrow_inner_end_y    4779
# right_eyebrow_outer_end_x    4813
# right_eyebrow_outer_end_y    4813
# nose_tip_x                      0
# nose_tip_y                      0
# mouth_left_corner_x          4780
# mouth_left_corner_y          4780
# mouth_right_corner_x         4779
# mouth_right_corner_y         4779
# mouth_center_top_lip_x       4774
# ...

# %%
df.fillna(method ='ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# left_eye_center_x            0
# left_eye_center_y            0
# right_eye_center_x           0
# right_eye_center_y           0
# left_eye_inner_corner_x      0
# left_eye_inner_corner_y      0
# left_eye_outer_corner_x      0
# left_eye_outer_corner_y      0
# right_eye_inner_corner_x     0
# right_eye_inner_corner_y     0
# right_eye_outer_corner_x     0
# right_eye_outer_corner_y     0
# left_eyebrow_inner_end_x     0
# left_eyebrow_inner_end_y     0
# left_eyebrow_outer_end_x     0
# left_eyebrow_outer_end_y     0
# right_eyebrow_inner_end_x    0
# right_eyebrow_inner_end_y    0
# right_eyebrow_outer_end_x    0
# right_eyebrow_outer_end_y    0
# nose_tip_x                   0
# nose_tip_y                   0
# mouth_left_corner_x          0
# mouth_left_corner_y          0
# mouth_right_corner_x         0
# mouth_right_corner_y         0
# mouth_center_top_lip_x       0
# mouth_center_top_lip_y       0
# mouth_center_bottom_lip_x    0
# mouth_center_bottom_lip_y    0
# ...

# %%
im1 = df.loc[0,'Image']

# %%
im1
# Out:
# '238 236 237 238 240 240 239 241 241 243 240 239 231 212 190 173 148 122 104 92 79 73 74 73 73 74 81 74 60 64 75 86 93 102 100 105 109 114 121 127 132 134 137 137 140 139 138 137 137 140 141 143 144 147 148 149 147 147 148 145 147 144 146 147 147 143 134 130 130 128 116 104 98 90 82 78 85 88 86 80 77 87 108 111 115 128 133 188 242 252 250 248 251 250 250 250 235 238 236 238 238 237 238 242 241 239 237 233 215 195 187 156 119 103 93 78 68 73 75 75 72 75 70 61 66 77 91 96 106 108 113 120 125 131 134 138 135 138 139 145 144 144 142 140 141 141 148 147 150 149 152 151 149 150 147 148 144 148 144 146 146 143 139 128 132 135 128 112 104 97 87 78 79 83 85 83 75 75 89 109 111 117 117 130 194 243 251 249 250 249 250 251 237 236 237 238 237 238 241 238 238 238 241 221 195 187 163 124 106 95 81 68 70 73 73 72 73 69 65 74 82 94 103 110 111 119 127 135 140 139 144 144 145 143 143 143 146 144 144 147 146 148 147 150 146 147 150 150 149 147 147 144 147 144 149 146 144 144 144 140 131 133 133 125 11
# ...

# %%
len(im1)
# Out:
# 33593

# %%
im1 = im1.split(' ')

# %%
len(im1) # 96x96 = 9216
# Out:
# 9216

# %%
im1 = np.array(im1, dtype='int32').reshape(96,96)

# %%
from matplotlib import pyplot as plt

plt.imshow(im1)
plt.show()

# %%
df.Image.dtype
# Out:
# dtype('O')

# %%
# imarr = np.fromstring(str(df.Image), dtype='int32', sep=' ')

# %%
from PIL import Image

# %%
imarr = np.fromstring(df.Image[0], dtype='int32', sep=' ')

# %%
imarr
# Out:
# array([238, 236, 237, ...,  70,  75,  90], dtype=int32)

# %%
type(imarr)
# Out:
# numpy.ndarray

# %%
imarr.reshape(96, 96)
# Out:
# array([[238, 236, 237, ..., 250, 250, 250],
#        [235, 238, 236, ..., 249, 250, 251],
#        [237, 236, 237, ..., 251, 251, 250],
#        ...,
#        [186, 183, 181, ...,  52,  57,  60],
#        [189, 188, 207, ...,  61,  69,  78],
#        [191, 184, 184, ...,  70,  75,  90]], dtype=int32)

# %%
Image.fromarray(imarr.reshape(96, 96))
# Out:
# <PIL.Image.Image image mode=I size=96x96 at 0x7F233C842CD0>

# %%
imarr.reshape(96, 96).shape
# Out:
# (96, 96)

# %%
plt.imshow(imarr.reshape(96, 96))
plt.show()

# %%
type(Image.fromarray(np.uint8(imarr.reshape(96, 96))))
# Out:
# PIL.Image.Image

# %%
np.uint8(imarr.reshape(96, 96))
# Out:
# array([[238, 236, 237, ..., 250, 250, 250],
#        [235, 238, 236, ..., 249, 250, 251],
#        [237, 236, 237, ..., 251, 251, 250],
#        ...,
#        [186, 183, 181, ...,  52,  57,  60],
#        [189, 188, 207, ...,  61,  69,  78],
#        [191, 184, 184, ...,  70,  75,  90]], dtype=uint8)

# %%
PILImage(Image.fromarray(np.uint8(imarr.reshape(96, 96))))
# Out:
# PILImage mode=L size=96x96

# %%
type(PILImage(Image.fromarray(np.uint8(imarr.reshape(96, 96)))))
# Out:
# fastai.vision.core.PILImage

# %%
np.reshape(df.iloc[0,:-1].values,(-1,2)).astype('float64')
# Out:
# array([[66.03356391, 39.00227368],
#        [30.22700752, 36.4216782 ],
#        [59.58207519, 39.64742256],
#        [73.13034586, 39.96999699],
#        [36.35657143, 37.3894015 ],
#        [23.45287218, 37.3894015 ],
#        [56.95326316, 29.03364812],
#        [80.22712782, 32.22813835],
#        [40.22760902, 29.0023218 ],
#        [16.35637895, 29.64747068],
#        [44.42057143, 57.06680301],
#        [61.19530827, 79.97016541],
#        [28.61449624, 77.38899248],
#        [43.3126015 , 72.93545865],
#        [43.13070677, 84.48577444]])

# %%
def df2img(r):
  imarr = np.fromstring(r.Image, dtype='int32', sep=' ')
  return PILImage(Image.fromarray(np.uint8(imarr.reshape(-1, 96))))

def df2label(r):
  return np.reshape(r[0:30].values,(-1,2)).astype('float64')

# %%
db = DataBlock(
                blocks = (ImageBlock, PointBlock),
                get_x = df2img,
                get_y = df2label,
                splitter = RandomSplitter(valid_pct=0.2, seed=6),
#                 batch_tfms = aug_transforms(do_flip=False)
)

# %%
dls = db.dataloaders(df)

# %%
dls.show_batch()

# %%
dls.valid.show_batch()

# %%
learn = cnn_learner(dls, resnet18)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# ...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=tensor(0.0021))
