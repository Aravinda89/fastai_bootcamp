# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravinda89/fastai_bootcamp/blob/main/Gayan_DL201_FaceKeyPoints.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastbook kaggle waterfallcharts treeinterpreter dtreeviz
import fastbook
fastbook.setup_book()
import os
from fastbook import *
from IPython.display import Image, display_svg, SVG

from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# !pip install kaggle
# Out:
# Mounted at /content/gdrive
# ...

# %%
import pandas as pd
from PIL import Image
from skimage import io
from skimage.transform import resize

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/DataSets/f_keypoints/"
# %cd /content/gdrive/MyDrive/DataSets/f_keypoints/
# Out:
# /content/gdrive/MyDrive/DataSets/f_keypoints

# %% [markdown]
# Download Data

# %%
# !kaggle competitions download -c facial-keypoints-detection

# %%
ls
# Out:
# IdLookupTable.csv  models/               test.csv  training.csv
# kaggle.json        SampleSubmission.csv  test.zip  training.zip

# %%
# file_extract('training.zip')
# file_extract('test.zip')

# %% [markdown]
# Load Data

# %%
# df = pd.read_csv('training.csv')
# df

# %%
df = pd.read_csv('training.csv',header='infer')
df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 7044          67.402546          31.842551           29.746749
# 7045          66.134400          38.365501           30.478626
# 7046          66.690732          36.845221           31.666420
# 7047          70.965082          39.853666           30.543285
# 7048          66.938311          43.424510           31.096059
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
df.shape
# Out:
# (7049, 31)

# %%
df.columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y', 'Image'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 31

# %%
df.loc[0,'left_eye_center_x']
# Out:
# 66.0335639098

# %%
df.loc[0,'left_eye_center_y']
# Out:
# 39.0022736842

# %%
df.loc[0,'Image']
# Out:
# '238 236 237 238 240 240 239 241 241 243 240 239 231 212 190 173 148 122 104 92 79 73 74 73 73 74 81 74 60 64 75 86 93 102 100 105 109 114 121 127 132 134 137 137 140 139 138 137 137 140 141 143 144 147 148 149 147 147 148 145 147 144 146 147 147 143 134 130 130 128 116 104 98 90 82 78 85 88 86 80 77 87 108 111 115 128 133 188 242 252 250 248 251 250 250 250 235 238 236 238 238 237 238 242 241 239 237 233 215 195 187 156 119 103 93 78 68 73 75 75 72 75 70 61 66 77 91 96 106 108 113 120 125 131 134 138 135 138 139 145 144 144 142 140 141 141 148 147 150 149 152 151 149 150 147 148 144 148 144 146 146 143 139 128 132 135 128 112 104 97 87 78 79 83 85 83 75 75 89 109 111 117 117 130 194 243 251 249 250 249 250 251 237 236 237 238 237 238 241 238 238 238 241 221 195 187 163 124 106 95 81 68 70 73 73 72 73 69 65 74 82 94 103 110 111 119 127 135 140 139 144 144 145 143 143 143 146 144 144 147 146 148 147 150 146 147 150 150 149 147 147 144 147 144 149 146 144 144 144 140 131 133 133 125 11
# ...

# %%
len(df.loc[6,'Image'])
# Out:
# 32214

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum()
# Out:
# left_eye_center_x              10
# left_eye_center_y              10
# right_eye_center_x             13
# right_eye_center_y             13
# left_eye_inner_corner_x      4778
# left_eye_inner_corner_y      4778
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# left_eyebrow_inner_end_x     4779
# left_eyebrow_inner_end_y     4779
# left_eyebrow_outer_end_x     4824
# left_eyebrow_outer_end_y     4824
# right_eyebrow_inner_end_x    4779
# right_eyebrow_inner_end_y    4779
# right_eyebrow_outer_end_x    4813
# right_eyebrow_outer_end_y    4813
# nose_tip_x                      0
# nose_tip_y                      0
# mouth_left_corner_x          4780
# mouth_left_corner_y          4780
# mouth_right_corner_x         4779
# mouth_right_corner_y         4779
# mouth_center_top_lip_x       4774
# ...

# %%
# Fill missing values
df.fillna(method ='ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# left_eye_center_x            0
# left_eye_center_y            0
# right_eye_center_x           0
# right_eye_center_y           0
# left_eye_inner_corner_x      0
# left_eye_inner_corner_y      0
# left_eye_outer_corner_x      0
# left_eye_outer_corner_y      0
# right_eye_inner_corner_x     0
# right_eye_inner_corner_y     0
# right_eye_outer_corner_x     0
# right_eye_outer_corner_y     0
# left_eyebrow_inner_end_x     0
# left_eyebrow_inner_end_y     0
# left_eyebrow_outer_end_x     0
# left_eyebrow_outer_end_y     0
# right_eyebrow_inner_end_x    0
# right_eyebrow_inner_end_y    0
# right_eyebrow_outer_end_x    0
# right_eyebrow_outer_end_y    0
# nose_tip_x                   0
# nose_tip_y                   0
# mouth_left_corner_x          0
# mouth_left_corner_y          0
# mouth_right_corner_x         0
# mouth_right_corner_y         0
# mouth_center_top_lip_x       0
# mouth_center_top_lip_y       0
# mouth_center_bottom_lip_x    0
# mouth_center_bottom_lip_y    0
# ...

# %%
im1 = df.loc[0,'Image']

# %%
im1
# Out:
# '238 236 237 238 240 240 239 241 241 243 240 239 231 212 190 173 148 122 104 92 79 73 74 73 73 74 81 74 60 64 75 86 93 102 100 105 109 114 121 127 132 134 137 137 140 139 138 137 137 140 141 143 144 147 148 149 147 147 148 145 147 144 146 147 147 143 134 130 130 128 116 104 98 90 82 78 85 88 86 80 77 87 108 111 115 128 133 188 242 252 250 248 251 250 250 250 235 238 236 238 238 237 238 242 241 239 237 233 215 195 187 156 119 103 93 78 68 73 75 75 72 75 70 61 66 77 91 96 106 108 113 120 125 131 134 138 135 138 139 145 144 144 142 140 141 141 148 147 150 149 152 151 149 150 147 148 144 148 144 146 146 143 139 128 132 135 128 112 104 97 87 78 79 83 85 83 75 75 89 109 111 117 117 130 194 243 251 249 250 249 250 251 237 236 237 238 237 238 241 238 238 238 241 221 195 187 163 124 106 95 81 68 70 73 73 72 73 69 65 74 82 94 103 110 111 119 127 135 140 139 144 144 145 143 143 143 146 144 144 147 146 148 147 150 146 147 150 150 149 147 147 144 147 144 149 146 144 144 144 140 131 133 133 125 11
# ...

# %%
len(im1)
# Out:
# 33593

# %%
im1 = im1.split(' ')

# %%
len(im1) # 96x96 = 9216
# Out:
# 9216

# %%
im1 = np.array(im1, dtype='int32').reshape(96,96)

# %%
from matplotlib import pyplot as plt

plt.imshow(im1)
plt.show()

# %%
df.Image.dtype
# Out:
# dtype('O')

# %%
imarr = np.fromstring(df.Image[0], dtype='int32', sep=' ')

# %%
imarr
# Out:
# array([238, 236, 237, ...,  70,  75,  90], dtype=int32)

# %%
type(imarr)
# Out:
# numpy.ndarray

# %%
imarr.reshape(96, 96)
# Out:
# array([[238, 236, 237, ..., 250, 250, 250],
#        [235, 238, 236, ..., 249, 250, 251],
#        [237, 236, 237, ..., 251, 251, 250],
#        ...,
#        [186, 183, 181, ...,  52,  57,  60],
#        [189, 188, 207, ...,  61,  69,  78],
#        [191, 184, 184, ...,  70,  75,  90]], dtype=int32)

# %%
imarr.reshape(96, 96).shape
# Out:
# (96, 96)

# %%
plt.imshow(imarr.reshape(96, 96))
plt.show()

# %%
type(Image.fromarray(np.uint8(imarr.reshape(96, 96))))
# Out:
# PIL.Image.Image

# %%
np.uint8(imarr.reshape(96, 96))
# Out:
# array([[238, 236, 237, ..., 250, 250, 250],
#        [235, 238, 236, ..., 249, 250, 251],
#        [237, 236, 237, ..., 251, 251, 250],
#        ...,
#        [186, 183, 181, ...,  52,  57,  60],
#        [189, 188, 207, ...,  61,  69,  78],
#        [191, 184, 184, ...,  70,  75,  90]], dtype=uint8)

# %%
PILImage(Image.fromarray(np.uint8(imarr.reshape(96, 96))))
# Out:
# PILImage mode=L size=96x96

# %%
type(PILImage(Image.fromarray(np.uint8(imarr.reshape(96, 96)))))
# Out:
# fastai.vision.core.PILImage

# %%
np.reshape(df.iloc[0,:-1].values,(-1,2)).astype('float64')
# Out:
# array([[66.03356391, 39.00227368],
#        [30.22700752, 36.4216782 ],
#        [59.58207519, 39.64742256],
#        [73.13034586, 39.96999699],
#        [36.35657143, 37.3894015 ],
#        [23.45287218, 37.3894015 ],
#        [56.95326316, 29.03364812],
#        [80.22712782, 32.22813835],
#        [40.22760902, 29.0023218 ],
#        [16.35637895, 29.64747068],
#        [44.42057143, 57.06680301],
#        [61.19530827, 79.97016541],
#        [28.61449624, 77.38899248],
#        [43.3126015 , 72.93545865],
#        [43.13070677, 84.48577444]])

# %%
def df2img(r):
  imarr = np.fromstring(r.Image, dtype='int32', sep=' ')
  return PILImage(Image.fromarray(np.uint8(imarr.reshape(-1, 96))))

def df2label(r):
  return np.reshape(r[0:30].values,(-1,2)).astype('float64')

# %%
db = DataBlock(
                blocks = (ImageBlock, PointBlock),
                get_x = df2img,
                get_y = df2label,
                splitter = RandomSplitter(valid_pct=0.2, seed=6),
)

# %%
dls = db.dataloaders(df)

# %%
dls.show_batch()

# %%
dls.valid.show_batch()

# %%
learn = cnn_learner(dls, resnet18)

# %%
learn.summary()
# Out:
# Sequential (Input shape: 64)
# ...
# Layer (type)         Output Shape         Param #    Trainable
# ...
#                      64 x 64 x 48 x 48
# Conv2d                                    9408       True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ReLU
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ReLU
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 128 x 12 x 12
# Conv2d                                    73728      True
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=tensor(0.0012))

# %%
learn.fit_one_cycle(5, 0.0012)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.782645</td>
#       <td>0.504113</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.334256</td>
#       <td>0.132024</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.611218</td>
#       <td>0.044789</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.336247</td>
#       <td>0.024281</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.252124</td>
#       <td>0.020792</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

learn.lr_find()
# Out:
# SuggestedLRs(valley=tensor(0.0012))

# %%
learn.fit_one_cycle(5, 0.0012)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.190990</td>
#       <td>0.144514</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.119556</td>
#       <td>0.072589</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.074769</td>
#       <td>0.054230</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.049070</td>
#       <td>0.006956</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.038867</td>
#       <td>0.004486</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.export('/content/gdrive/MyDrive/Colab Notebooks/models/Face_keypoints_val_loss_0.004.pkl')
learn = load_learner('/content/gdrive/MyDrive/Colab Notebooks/models/Face_keypoints_val_loss_0.004.pkl')

# %%
learn.show_results()

# %%
learn.fit_one_cycle(5, 0.0012)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.038046</td>
#       <td>0.009627</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.038820</td>
#       <td>0.062611</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.034179</td>
#       <td>0.010133</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022490</td>
#       <td>0.007573</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019250</td>
#       <td>0.004753</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
# Data Augmentation

# %%
db = DataBlock(
                blocks = (ImageBlock, PointBlock),
                get_x = df2img,
                get_y = df2label,
                splitter = RandomSplitter(valid_pct=0.2, seed=6),
               batch_tfms = aug_transforms(do_flip=False),
)

# %%
dls = db.dataloaders(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet18)

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=tensor(0.0030))

# %%
learn.fit_one_cycle(5, 0.0030)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.266993</td>
#       <td>0.374109</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.636433</td>
#       <td>0.036642</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.169549</td>
#       <td>0.016005</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.059953</td>
#       <td>0.006270</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.035612</td>
#       <td>0.005959</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

learn.lr_find()
# Out:
# SuggestedLRs(valley=tensor(0.0003))

# %%
learn.fit_one_cycle(5, 0.0003)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027887</td>
#       <td>0.014944</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.022028</td>
#       <td>0.005197</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.019522</td>
#       <td>0.004753</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016025</td>
#       <td>0.003519</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.014075</td>
#       <td>0.003469</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()

# %%
# learn.export('/content/gdrive/MyDrive/Colab Notebooks/models/Face_keypoints_val_loss_0.003.pkl')
learn = load_learner('/content/gdrive/MyDrive/Colab Notebooks/models/Face_keypoints_val_loss_0.003.pkl')

# %% [markdown]
# Test image Prediction

# %%
df_test = pd.read_csv('test.csv',index_col='ImageId')
df_test.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Image
# ImageId
# ...

# %%
len(df_test)
# Out:
# 1783

# %%
def df2img(r):
  imarr = np.fromstring(r.Image, dtype='int32', sep=' ')
  return PILImage(Image.fromarray(np.uint8(imarr.reshape(-1, 96))))

# %% [markdown]
# Predict Random Test Image

# %%
def predict_random_img(df_test):
  idx = random.choice(range(len(df_test)))   # Choose Random image
  imarr = np.fromstring(df_test.loc[idx,'Image'], dtype='int32', sep=' ')
  imgt = PILImage(Image.fromarray(np.uint8(imarr.reshape(-1, 96))))
  print(imgt.shape)
  pnt_img = TensorImage(imgt)   # convert image into TensorImage

  pred = learn.predict(imgt)  # Predict
  tpnts = pred[0]

  ctx = pnt_img.show() # Plot 
  tpnts.show(ctx=ctx)

# %%
predict_random_img(df_test)
# Out:
# (96, 96)

# %%
imgs = glob.glob('/content/gdrive/MyDrive/models/face/*.jpeg')
img_path = random.choice(imgs)
img = io.imread(img_path, as_gray=True)
gray_im = resize(img, (96, 96))

im = PILImage.create(gray_im)
pnt_img = TensorImage(im)

pred = learn.predict(im)
tpnts = pred[0]

ctx = pnt_img.show() 
tpnts.show(ctx=ctx)
